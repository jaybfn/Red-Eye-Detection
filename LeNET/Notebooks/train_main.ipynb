# %%
# importing libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Dropout
from tensorflow.keras.activations import relu, softmax
from tensorflow.keras.models import Sequential
from tensorflow.keras import backend as K
from keras import regularizers
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
import cv2
from keras.regularizers import l2, l1

from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import plot_roc_curve

plt.style.use('fivethirtyeight')

# %%
train_data_path = '../../data/aug_red_eye/training_aug/train'
val_data_path = '../../data/aug_red_eye/training_aug/val'
test_data_path = '../../data/aug_red_eye/training_aug/test'

# %%
# define the classes for training
classes = os.listdir(train_data_path)
print(classes)
X_list = []
y_list = []
for class_ in classes:
    files = os.listdir(train_data_path + '/' + class_)
    #print(files)
    for file in files:
        img = load_img(path=train_data_path + '/' + class_+'/'+f'{file}',target_size=(128,128))
        x = np.array(img)
        X_list.append(x)
        y_list.append(class_)
        
X = np.array(X_list)/255
y = np.array(y_list)
# Out:
# ['normal_eye_aug', 'red_eye_aug']

# %%
X[0].shape
# Out:
# (128, 128, 3)

# %%
y_series = pd.Series(y).map({classes[0]:0, classes[1]:1})
y = to_categorical(y_series)
#print(y_series)

# %%
# define the classes for val
classes = os.listdir(val_data_path)

X_list = []
y_list = []
for class_ in classes:
    files = os.listdir(val_data_path + '/' + class_)
    #print(files)
    for file in files:
        img = load_img(path=val_data_path + '/' + class_+'/'+f'{file}',target_size=(128,128))
        x = np.array(img)
        X_list.append(x)
        y_list.append(class_)
        
X_val = np.array(X_list)/255
y_val = np.array(y_list)

# %%
y_series_val = pd.Series(y_val).map({classes[0]:0, classes[1]:1})
y_val = to_categorical(y_series_val)

# %%
#print(y_val)

# %%
K.clear_session()

#defining the CNN2D model
model = Sequential([

    Conv2D(filters= 6, kernel_size=(3,3), strides=(1,1), input_shape=X[0].shape,
           activation=keras.activations.relu,
           padding='valid',kernel_regularizer=l2(0.0001)), # valid means no padding  #

    MaxPooling2D(pool_size=(2,2), strides=(2,2), padding= 'valid'),
    
    Conv2D(filters = 16, kernel_size=(3,3),strides=(1,1),
           activation=keras.activations.relu, 
           padding = 'valid',kernel_regularizer=l2(0.0001)), # valid means no padding #,kernel_regularizer=l2(0.0001)
    
    MaxPooling2D(pool_size=(2,2), strides=(2,2), padding= 'valid'), # valid means no padding
    
    Flatten(),
    
    # Fully connected dense layer with relu activation function
    Dropout(0.3),
    Dense(units=64, activation=keras.activations.relu),
    BatchNormalization(),
    
    # Fully connected dense layer with relu activation function
#     Dropout(0.2),
#     Dense(units=128, activation=keras.activations.relu),
#     BatchNormalization(),

    # Fully connected dense layer with relu activation function
    Dropout(0.3),
    Dense(units=32, activation=keras.activations.relu),
    BatchNormalization(),

    # Fully connected dense layer with relu activation function
    Dropout(0.3),
    Dense(units=16, activation=keras.activations.relu),
    BatchNormalization(),

    # Fully connected output layer with softmax
    Dense(units=2, activation=keras.activations.sigmoid)   # How many neurons? we want classify two classes
    
])

# %%
# compling the model
model.compile(optimizer=keras.optimizers.Adam(0.5e-4), 
                loss=keras.losses.binary_crossentropy, metrics=['accuracy','Recall','Precision'])

cb = keras.callbacks.EarlyStopping(monitor="accuracy",
                                    min_delta=0.005,
                                    patience=30,
                                    verbose=1,
                                    mode="min",
                                    baseline=None,
                                    restore_best_weights=False)

# %%
history = model.fit(X,y,
        batch_size = 50, 
        epochs = 150,
        verbose = 1, 
        validation_data = (X_val, y_val))
# Out:
# Epoch 1/150
# 19/19 [==============================] - 11s 66ms/step - loss: 0.9238 - accuracy: 0.5279 - recall: 0.5395 - precision: 0.5311 - val_loss: 0.6941 - val_accuracy: 0.4970 - val_recall: 0.4852 - val_precision: 0.4940
# Epoch 2/150
# 19/19 [==============================] - 0s 17ms/step - loss: 0.8606 - accuracy: 0.5711 - recall: 0.5638 - precision: 0.5544 - val_loss: 0.6954 - val_accuracy: 0.5030 - val_recall: 0.4852 - val_precision: 0.5031
# Epoch 3/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.7994 - accuracy: 0.6101 - recall: 0.5753 - precision: 0.5858 - val_loss: 0.6940 - val_accuracy: 0.4970 - val_recall: 0.4911 - val_precision: 0.5061
# Epoch 4/150
# 19/19 [==============================] - 0s 17ms/step - loss: 0.7542 - accuracy: 0.6354 - recall: 0.6059 - precision: 0.5996 - val_loss: 0.6958 - val_accuracy: 0.5030 - val_recall: 0.4852 - val_precision: 0.5062
# Epoch 5/150
# 19/19 [==============================] - 0s 17ms/step - loss: 0.7408 - accuracy: 0.6417 - recall: 0.5985 - precision: 0.5998 - val_loss: 0.6947 - val_accuracy: 0.5030 - val_recall: 0.4911 - val_precision: 0.5092
# Epoch 6/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.6973 - accuracy: 0.6776 - recall: 0.6301 - precision: 0.6315 - val_loss: 0.6957 - val_accuracy: 0.5030 - val_recall: 0.4970 - val_precision: 0.5000
# Epoch 7/150
# 19/19 [==============================] - 0s 17ms/step - loss: 0.6704 - accuracy: 0.6828 - recall: 0.6575 - precision: 0.6393 - val_loss: 0.6924 - val_accuracy: 0.4970 - val_recall: 0.4497 - val_precision: 0.4872
# Epoch 8/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.6034 - accuracy: 0.7387 - recall: 0.6860 - precision: 0.6911 - val_loss: 0.6931 - val_accuracy: 0.4970 - val_recall: 0.4497 - val_precision: 0.5241
# Epoch 9/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.6155 - accuracy: 0.7260 - recall: 0.6639 - precision: 0.6767 - val_loss: 0.6912 - val_accuracy: 0.4970 - val_recall: 0.4142 - val_precision: 0.5556
# Epoch 10/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.5879 - accuracy: 0.7239 - recall: 0.6902 - precision: 0.7081 - val_loss: 0.6889 - val_accuracy: 0.4970 - val_recall: 0.4083 - val_precision: 0.5702
# Epoch 11/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.5693 - accuracy: 0.7439 - recall: 0.6891 - precision: 0.7047 - val_loss: 0.6870 - val_accuracy: 0.4970 - val_recall: 0.4142 - val_precision: 0.5426
# Epoch 12/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.5472 - accuracy: 0.7640 - recall: 0.7028 - precision: 0.7172 - val_loss: 0.6818 - val_accuracy: 0.4970 - val_recall: 0.4142 - val_precision: 0.5224
# Epoch 13/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.5221 - accuracy: 0.7850 - recall: 0.7513 - precision: 0.7505 - val_loss: 0.6740 - val_accuracy: 0.4793 - val_recall: 0.3905 - val_precision: 0.5739
# Epoch 14/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.5015 - accuracy: 0.8135 - recall: 0.7482 - precision: 0.7561 - val_loss: 0.6669 - val_accuracy: 0.4852 - val_recall: 0.4201 - val_precision: 0.6017
# Epoch 15/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.4908 - accuracy: 0.8061 - recall: 0.7608 - precision: 0.7648 - val_loss: 0.6587 - val_accuracy: 0.5325 - val_recall: 0.4260 - val_precision: 0.6050
# Epoch 16/150
# 19/19 [==============================] - 0s 17ms/step - loss: 0.4689 - accuracy: 0.8356 - recall: 0.7682 - precision: 0.7780 - val_loss: 0.6457 - val_accuracy: 0.5680 - val_recall: 0.4260 - val_precision: 0.6606
# Epoch 17/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.4772 - accuracy: 0.8093 - recall: 0.7640 - precision: 0.7779 - val_loss: 0.6373 - val_accuracy: 0.5680 - val_recall: 0.4615 - val_precision: 0.6500
# Epoch 18/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.4677 - accuracy: 0.8261 - recall: 0.7661 - precision: 0.7851 - val_loss: 0.6218 - val_accuracy: 0.6036 - val_recall: 0.5207 - val_precision: 0.6667
# Epoch 19/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.4426 - accuracy: 0.8493 - recall: 0.7924 - precision: 0.8060 - val_loss: 0.6119 - val_accuracy: 0.6391 - val_recall: 0.5266 - val_precision: 0.7120
# Epoch 20/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.4358 - accuracy: 0.8535 - recall: 0.7966 - precision: 0.8129 - val_loss: 0.6078 - val_accuracy: 0.6272 - val_recall: 0.5385 - val_precision: 0.7109
# Epoch 21/150
# 19/19 [==============================] - 0s 17ms/step - loss: 0.4199 - accuracy: 0.8567 - recall: 0.7998 - precision: 0.8197 - val_loss: 0.5972 - val_accuracy: 0.6450 - val_recall: 0.5799 - val_precision: 0.6950
# Epoch 22/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.4193 - accuracy: 0.8630 - recall: 0.7945 - precision: 0.8295 - val_loss: 0.5868 - val_accuracy: 0.6686 - val_recall: 0.5976 - val_precision: 0.7113
# Epoch 23/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.4015 - accuracy: 0.8736 - recall: 0.8261 - precision: 0.8376 - val_loss: 0.5766 - val_accuracy: 0.6923 - val_recall: 0.6095 - val_precision: 0.7254
# Epoch 24/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.3789 - accuracy: 0.8925 - recall: 0.8240 - precision: 0.8519 - val_loss: 0.5572 - val_accuracy: 0.7278 - val_recall: 0.6627 - val_precision: 0.7517
# Epoch 25/150
# 19/19 [==============================] - 0s 17ms/step - loss: 0.3789 - accuracy: 0.8904 - recall: 0.8430 - precision: 0.8602 - val_loss: 0.5546 - val_accuracy: 0.7278 - val_recall: 0.6627 - val_precision: 0.7417
# Epoch 26/150
# 19/19 [==============================] - 0s 18ms/step - loss: 0.3835 - accuracy: 0.8830 - recall: 0.8356 - precision: 0.8499 - val_loss: 0.5449 - val_accuracy: 0.7515 - val_recall: 0.7041 - val_precision: 0.7437
# Epoch 27/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.3561 - accuracy: 0.9009 - recall: 0.8483 - precision: 0.8779 - val_loss: 0.5378 - val_accuracy: 0.7633 - val_recall: 0.7101 - val_precision: 0.7742
# Epoch 28/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.3593 - accuracy: 0.8988 - recall: 0.8535 - precision: 0.8535 - val_loss: 0.5393 - val_accuracy: 0.7692 - val_recall: 0.7160 - val_precision: 0.7610
# Epoch 29/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.3545 - accuracy: 0.8988 - recall: 0.8588 - precision: 0.8652 - val_loss: 0.5408 - val_accuracy: 0.7456 - val_recall: 0.7041 - val_precision: 0.7391
# Epoch 30/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.3261 - accuracy: 0.9178 - recall: 0.8725 - precision: 0.8894 - val_loss: 0.5444 - val_accuracy: 0.7515 - val_recall: 0.7101 - val_precision: 0.7317
# Epoch 31/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.3373 - accuracy: 0.9041 - recall: 0.8672 - precision: 0.8691 - val_loss: 0.5372 - val_accuracy: 0.7396 - val_recall: 0.7101 - val_precision: 0.7362
# Epoch 32/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.3275 - accuracy: 0.9073 - recall: 0.8767 - precision: 0.8832 - val_loss: 0.5353 - val_accuracy: 0.7396 - val_recall: 0.7278 - val_precision: 0.7410
# Epoch 33/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.3183 - accuracy: 0.9241 - recall: 0.8862 - precision: 0.8937 - val_loss: 0.5290 - val_accuracy: 0.7396 - val_recall: 0.7396 - val_precision: 0.7530
# Epoch 34/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.3254 - accuracy: 0.9146 - recall: 0.8736 - precision: 0.8819 - val_loss: 0.5280 - val_accuracy: 0.7456 - val_recall: 0.7633 - val_precision: 0.7500
# Epoch 35/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.3003 - accuracy: 0.9252 - recall: 0.8978 - precision: 0.9045 - val_loss: 0.5308 - val_accuracy: 0.7515 - val_recall: 0.7574 - val_precision: 0.7314
# Epoch 36/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.3034 - accuracy: 0.9262 - recall: 0.8851 - precision: 0.9023 - val_loss: 0.5336 - val_accuracy: 0.7219 - val_recall: 0.7515 - val_precision: 0.7341
# Epoch 37/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.2908 - accuracy: 0.9315 - recall: 0.8957 - precision: 0.9023 - val_loss: 0.5414 - val_accuracy: 0.7337 - val_recall: 0.7396 - val_precision: 0.7396
# Epoch 38/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.2808 - accuracy: 0.9420 - recall: 0.9125 - precision: 0.9097 - val_loss: 0.5471 - val_accuracy: 0.7337 - val_recall: 0.7337 - val_precision: 0.7337
# Epoch 39/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.2862 - accuracy: 0.9326 - recall: 0.8978 - precision: 0.9073 - val_loss: 0.5444 - val_accuracy: 0.7337 - val_recall: 0.7160 - val_precision: 0.7378
# Epoch 40/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.2697 - accuracy: 0.9526 - recall: 0.9115 - precision: 0.9202 - val_loss: 0.5360 - val_accuracy: 0.7278 - val_recall: 0.7160 - val_precision: 0.7246
# Epoch 41/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.2652 - accuracy: 0.9442 - recall: 0.9009 - precision: 0.9233 - val_loss: 0.5450 - val_accuracy: 0.7396 - val_recall: 0.7337 - val_precision: 0.7337
# Epoch 42/150
# 19/19 [==============================] - 0s 17ms/step - loss: 0.2696 - accuracy: 0.9336 - recall: 0.9125 - precision: 0.9174 - val_loss: 0.5469 - val_accuracy: 0.7337 - val_recall: 0.7337 - val_precision: 0.7251
# Epoch 43/150
# 19/19 [==============================] - 0s 17ms/step - loss: 0.2562 - accuracy: 0.9463 - recall: 0.9125 - precision: 0.9352 - val_loss: 0.5377 - val_accuracy: 0.7337 - val_recall: 0.7515 - val_precision: 0.7427
# Epoch 44/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.2434 - accuracy: 0.9568 - recall: 0.9378 - precision: 0.9359 - val_loss: 0.5406 - val_accuracy: 0.7456 - val_recall: 0.7633 - val_precision: 0.7414
# Epoch 45/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.2492 - accuracy: 0.9505 - recall: 0.9262 - precision: 0.9361 - val_loss: 0.5561 - val_accuracy: 0.7219 - val_recall: 0.7337 - val_precision: 0.7168
# Epoch 46/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.2494 - accuracy: 0.9505 - recall: 0.9199 - precision: 0.9180 - val_loss: 0.5505 - val_accuracy: 0.7396 - val_recall: 0.7396 - val_precision: 0.7310
# Epoch 47/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.2407 - accuracy: 0.9642 - recall: 0.9399 - precision: 0.9389 - val_loss: 0.5486 - val_accuracy: 0.7278 - val_recall: 0.7574 - val_precision: 0.7356
# Epoch 48/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.2258 - accuracy: 0.9642 - recall: 0.9315 - precision: 0.9424 - val_loss: 0.5489 - val_accuracy: 0.7456 - val_recall: 0.7515 - val_precision: 0.7515
# Epoch 49/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.2210 - accuracy: 0.9631 - recall: 0.9399 - precision: 0.9419 - val_loss: 0.5464 - val_accuracy: 0.7574 - val_recall: 0.7633 - val_precision: 0.7544
# Epoch 50/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.2249 - accuracy: 0.9589 - recall: 0.9420 - precision: 0.9440 - val_loss: 0.5591 - val_accuracy: 0.7278 - val_recall: 0.7456 - val_precision: 0.7326
# Epoch 51/150
# 19/19 [==============================] - 0s 17ms/step - loss: 0.2214 - accuracy: 0.9621 - recall: 0.9347 - precision: 0.9507 - val_loss: 0.5613 - val_accuracy: 0.7278 - val_recall: 0.7396 - val_precision: 0.7396
# Epoch 52/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.2117 - accuracy: 0.9715 - recall: 0.9463 - precision: 0.9563 - val_loss: 0.5747 - val_accuracy: 0.7396 - val_recall: 0.7396 - val_precision: 0.7353
# Epoch 53/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.2265 - accuracy: 0.9536 - recall: 0.9357 - precision: 0.9387 - val_loss: 0.5817 - val_accuracy: 0.7337 - val_recall: 0.7396 - val_precision: 0.7440
# Epoch 54/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.2043 - accuracy: 0.9652 - recall: 0.9484 - precision: 0.9585 - val_loss: 0.5731 - val_accuracy: 0.7396 - val_recall: 0.7396 - val_precision: 0.7225
# Epoch 55/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.2046 - accuracy: 0.9705 - recall: 0.9494 - precision: 0.9544 - val_loss: 0.5857 - val_accuracy: 0.7219 - val_recall: 0.7337 - val_precision: 0.7337
# Epoch 56/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1950 - accuracy: 0.9747 - recall: 0.9610 - precision: 0.9550 - val_loss: 0.5765 - val_accuracy: 0.7456 - val_recall: 0.7515 - val_precision: 0.7341
# Epoch 57/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.2045 - accuracy: 0.9705 - recall: 0.9484 - precision: 0.9524 - val_loss: 0.5706 - val_accuracy: 0.7633 - val_recall: 0.7633 - val_precision: 0.7544
# Epoch 58/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.2042 - accuracy: 0.9579 - recall: 0.9494 - precision: 0.9484 - val_loss: 0.5854 - val_accuracy: 0.7278 - val_recall: 0.7456 - val_precision: 0.7283
# Epoch 59/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1876 - accuracy: 0.9768 - recall: 0.9589 - precision: 0.9609 - val_loss: 0.5980 - val_accuracy: 0.7278 - val_recall: 0.7278 - val_precision: 0.7235
# Epoch 60/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1835 - accuracy: 0.9715 - recall: 0.9631 - precision: 0.9652 - val_loss: 0.6171 - val_accuracy: 0.7278 - val_recall: 0.7219 - val_precision: 0.7219
# Epoch 61/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1814 - accuracy: 0.9779 - recall: 0.9600 - precision: 0.9650 - val_loss: 0.6131 - val_accuracy: 0.7456 - val_recall: 0.7337 - val_precision: 0.7294
# Epoch 62/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1801 - accuracy: 0.9715 - recall: 0.9547 - precision: 0.9527 - val_loss: 0.6052 - val_accuracy: 0.7396 - val_recall: 0.7633 - val_precision: 0.7414
# Epoch 63/150
# 19/19 [==============================] - 0s 26ms/step - loss: 0.1702 - accuracy: 0.9852 - recall: 0.9642 - precision: 0.9713 - val_loss: 0.5915 - val_accuracy: 0.7337 - val_recall: 0.7515 - val_precision: 0.7427
# Epoch 64/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1777 - accuracy: 0.9715 - recall: 0.9642 - precision: 0.9632 - val_loss: 0.5859 - val_accuracy: 0.7396 - val_recall: 0.7633 - val_precision: 0.7544
# Epoch 65/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.
150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1255 - accuracy: 0.9895 - recall: 0.9831 - precision: 0.9800 - val_loss: 0.5960 - val_accuracy: 0.7751 - val_recall: 0.8047 - val_precision: 0.7727
# Epoch 82/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1322 - accuracy: 0.9842 - recall: 0.9800 - precision: 0.9789 - val_loss: 0.5962 - val_accuracy: 0.7633 - val_recall: 0.7692 - val_precision: 0.7738
# Epoch 83/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1199 - accuracy: 0.9916 - recall: 0.9874 - precision: 0.9874 - val_loss: 0.5989 - val_accuracy: 0.7692 - val_recall: 0.7633 - val_precision: 0.7725
# Epoch 84/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1298 - accuracy: 0.9852 - recall: 0.9800 - precision: 0.9800 - val_loss: 0.6167 - val_accuracy: 0.7692 - val_recall: 0.7692 - val_precision: 0.7738
# Epoch 85/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1190 - accuracy: 0.9926 - recall: 0.9842 - precision: 0.9873 - val_loss: 0.6182 - val_accuracy: 0.7811 - val_recall: 0.7929 - val_precision: 0.7836
# Epoch 86/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1230 - accuracy: 0.9852 - recall: 0.9800 - precision: 0.9800 - val_loss: 0.6340 - val_accuracy: 0.7692 - val_recall: 0.7751 - val_precision: 0.7572
# Epoch 87/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1259 - accuracy: 0.9895 - recall: 0.9779 - precision: 0.9779 - val_loss: 0.6409 - val_accuracy: 0.7515 - val_recall: 0.7633 - val_precision: 0.7544
# Epoch 88/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1140 - accuracy: 0.9937 - recall: 0.9916 - precision: 0.9823 - val_loss: 0.6290 - val_accuracy: 0.7633 - val_recall: 0.7751 - val_precision: 0.7616
# Epoch 89/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1205 - accuracy: 0.9905 - recall: 0.9884 - precision: 0.9853 - val_loss: 0.6258 - val_accuracy: 0.7692 - val_recall: 0.7751 - val_precision: 0.7529
# Epoch 90/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1124 - accuracy: 0.9926 - recall: 0.9842 - precision: 0.9852 - val_loss: 0.6149 - val_accuracy: 0.7692 - val_recall: 0.7988 - val_precision: 0.7670
# Epoch 91/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1084 - accuracy: 0.9905 - recall: 0.9874 - precision: 0.9863 - val_loss: 0.6133 - val_accuracy: 0.7692 - val_recall: 0.7929 - val_precision: 0.7614
# Epoch 92/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1051 - accuracy: 0.9916 - recall: 0.9895 - precision: 0.9874 - val_loss: 0.6170 - val_accuracy: 0.7692 - val_recall: 0.7988 - val_precision: 0.7714
# Epoch 93/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1091 - accuracy: 0.9937 - recall: 0.9884 - precision: 0.9895 - val_loss: 0.6103 - val_accuracy: 0.7811 - val_recall: 0.7870 - val_precision: 0.7644
# Epoch 94/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1054 - accuracy: 0.9884 - recall: 0.9863 - precision: 0.9832 - val_loss: 0.6143 - val_accuracy: 0.7633 - val_recall: 0.7751 - val_precision: 0.7706
# Epoch 95/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1122 - accuracy: 0.9926 - recall: 0.9810 - precision: 0.9852 - val_loss: 0.6161 - val_accuracy: 0.7633 - val_recall: 0.7811 - val_precision: 0.7674
# Epoch 96/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1042 - accuracy: 0.9905 - recall: 0.9831 - precision: 0.9852 - val_loss: 0.6183 - val_accuracy: 0.7751 - val_recall: 0.7811 - val_precision: 0.7765
# Epoch 97/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1076 - accuracy: 0.9916 - recall: 0.9884 - precision: 0.9853 - val_loss: 0.6211 - val_accuracy: 0.7633 - val_recall: 0.7751 - val_precision: 0.7661
# Epoch 98/150
# 19/19 [==============================] - 0s 15ms/step - loss: 0.
150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0532 - accuracy: 0.9968 - recall: 0.9947 - precision: 0.9968 - val_loss: 0.6398 - val_accuracy: 0.7988 - val_recall: 0.8047 - val_precision: 0.7953
# Epoch 148/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0572 - accuracy: 0.9947 - recall: 0.9937 - precision: 0.9916 - val_loss: 0.6300 - val_accuracy: 0.8284 - val_recall: 0.8343 - val_precision: 0.8343
# Epoch 149/150
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0473 - accuracy: 0.9989 - recall: 0.9989 - precision: 0.9979 - val_loss: 0.6385 - val_accuracy: 0.8107 - val_recall: 0.8225 - val_precision: 0.8129
# Epoch 150/150
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0578 - accuracy: 0.9937 - recall: 0.9895 - precision: 0.9926 - val_loss: 0.6386 - val_accuracy: 0.8166 - val_recall: 0.8225 - val_precision: 0.8176

# %%
train_score = model.evaluate(X, y)
print('val_loss =', train_score[0])
print('val_accuracy =', train_score[1])
# Out:
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0232 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# val_loss = 0.023236693814396858
# val_accuracy = 1.0

# %%
val_score = model.evaluate(X_val, y_val)
print('val_loss =', val_score[0])
print('val_accuracy =', val_score[1])
# Out:
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6386 - accuracy: 0.8166 - recall: 0.8225 - precision: 0.8176
# val_loss = 0.6386189460754395
# val_accuracy = 0.8165680766105652

# %%
pd.DataFrame(history.history).plot()
plt.grid(True)
plt.gca().set_ylim(0,1.1) # set the y range to [0,1]
plt.show()


# To save the model

model.save(r"model.h5")

# %%
# define the classes for val
classes = os.listdir(test_data_path)

X_list = []
y_list = []
for class_ in classes:
    files = os.listdir(test_data_path + '/' + class_)
    #print(files)
    for file in files:
        img = load_img(path=test_data_path + '/' + class_+'/'+f'{file}',target_size=(128,128))
        x = np.array(img)
        X_list.append(x)
        y_list.append(class_)
        
X_test = np.array(X_list)/255
y_test = np.array(y_list)

y_series_test = pd.Series(y_test).map({classes[0]:0, classes[1]:1})
print(len(y_series_test))
y_test = to_categorical(y_series_test)
# Out:
# 11

# %%
y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=-1)
cf_matrix = confusion_matrix(y_series_test, y_pred)
print(cf_matrix)
# Out:
# 1/1 [==============================] - 0s 319ms/step
# [[5 0]
#  [2 4]]

# %%
LABELS = ["Normal_Eye","Red_Eye"]
sns.heatmap(cf_matrix, annot=True, xticklabels=LABELS, yticklabels=LABELS,fmt = 'd')
plt.title("Confusion_Martix")
plt.ylabel("True class")
plt.xlabel("Predicted class")
plt.show()

# %%
print()
print('Model Evalution Score')
print(model.evaluate(X_test, y_test))
# Out:
# Model Evalution Score
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3900 - accuracy: 0.8182 - recall: 0.8182 - precision: 0.9000
# [0.3899874985218048, 0.8181818127632141, 0.8181818127632141, 0.8999999761581421]

# %%
image = cv2.imread('../../data/aug_red_eye/prediction_images/prediction/Red2.jpg') #
RGB_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
plt.show()

# %%
image = cv2.resize(image, (128,128), interpolation=cv2.INTER_AREA)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
incomming_image = np.array(image)/255
incomming_image_exp = np.expand_dims(incomming_image, axis = 0)

y_pred = model.predict(incomming_image_exp)
print(y_pred)
if y_pred[0][0] > y_pred[0][1]: 
    print(f'Normal Eye : prediction accuracy {round((y_pred[0][0]),2)*100}%')
else:
    print(f'Red Eye : prediction accuracy {round((y_pred[0][1]),2)*100}%')
# Out:
# 1/1 [==============================] - 0s 193ms/step
# [[0.09354764 0.91241115]]
# Red Eye : prediction accuracy 91.00000262260437%
